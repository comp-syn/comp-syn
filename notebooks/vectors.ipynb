# %% [markdown]
# ## comp-syn vectors
#
# This notebook demonstrates how to use the vectors class to get information about the color distributions of words. this class requires the images to already be downloaded and stored in a folder.
#
# We start with creating the vectors from a collection of images saved to disk.
#
# ### imports

# %%
import compsyn as cs
import PIL
from PIL import Image
import numpy as np

# %%
path = "/Users/bhargavvader/open_source/comp-syn/downloads/paper_categories"

# %%
love_vector = cs.vectors.Vector("love")

# %%
love_vector.load_from_folder(path)
# Out:
# [2020-06-08 19:55:18,751] (compsyn.ImageAnalysis)  INFO: love is being compressed.

# %%
love_vector.rgb_dist
# Out:
# array([1.40895633e-07, 7.41199147e-09, 8.63679137e-11, 5.33250120e-09,
#        1.23785039e-07, 1.61645538e-08, 2.79873735e-08, 1.60805576e-07])

# %%
love_vector.jzazbz_dist
# Out:
# array([ 43.70086125,  82.88902835,  20.36144642, 207.55729541,
#         11.45945804, 131.10485973,  10.49319587, 334.18735373])

# %%
love_vector.rgb_ratio
# Out:
# array([0.43899919, 0.27914204, 0.28185877])

# %%
love_vector.colorgram
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x13A25F050>

# %%
love_vector.print_word_color()

# %%
fear_vector = cs.vectors.Vector("fear")

# %%
fear_vector.load_from_folder(path)
# Out:
# [2020-06-08 19:55:22,184] (compsyn.ImageAnalysis)  INFO: fear is being compressed.

# %%
joy_vector = cs.vectors.Vector("joy")

# %%
joy_vector.load_from_folder(path)
# Out:
# [2020-06-08 19:55:26,693] (compsyn.ImageAnalysis)  INFO: joy is being compressed.

# %%
anger_vector = cs.vectors.Vector("anger")

# %%
anger_vector.load_from_folder(path)
# Out:
# [2020-06-08 19:55:30,056] (compsyn.ImageAnalysis)  INFO: anger is being compressed.

# %% [markdown]
# ### Loading pre-computed vectors
#
# We will now use the colorgram and vector meta data to load information for all the ~ 40,000 stored vectors.

# %%
path = "/Users/bhargavvader/open_source/comp-syn/vectors_data/"

# %%
disk_vectors = cs.vectors.LoadVectorsFromDisk(path)

# %%
len(disk_vectors.vectors)
# Out:
# 39949

# %%
disk_vectors.load_colorgram("plunger")

# %%
disk_vectors.vectors["plunger"].colorgram
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1130B0110>

# %%
disk_vectors.load_info_from_colorgram("plunger")

# %%
# this takes time and requires lots of ram!
# disk_vectors.load_info_from_all_colorgrams()
# disk_vectors.load_all_colorgrams()

# %%
disk_vectors.load_concreteness_data()

# %%
disk_vectors.vectors["plunger"].__dict__.keys()
# Out:
# dict_keys(['word', 'rgb_dist', 'jzazbz_dist', 'colorgram_vector', 'colorgram', 'rgb_vector', 'jzazbz_vector', 'conreteness_mean', 'conreteness_sd'])

# %% [markdown]
# The disk loaded vectors contain a rich amount of information about the word-color relationship!
