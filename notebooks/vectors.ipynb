# %% [markdown]
# ## comp-syn vectors
#
# This notebook demonstrates how to use the vectors class to get information about the color distributions of words. this class requires the images to already be downloaded and stored in a folder.
#
# ### imports

# %%
import compsyn as cs
import PIL
from PIL import Image
import numpy as np

# %%
path = "/Users/bhargavvader/open_source/comp-syn/downloads/paper_categories"

# %%
love_vector = cs.vectors.Vector("love", path)
# Out:
# love is being compressed.

# %%
love_vector.rgb_dist
# Out:
# array([3.28946109e-07, 3.40652379e-08, 1.02341917e-11, 1.42876626e-09,
#        1.64691902e-08, 3.97141462e-09, 1.64478080e-12, 8.46148346e-11,
#        5.82252404e-09, 1.26489857e-07, 3.77113515e-08, 4.57249063e-10,
#        2.66953407e-08, 7.85962161e-08, 1.23460902e-08, 1.23358560e-10,
#        2.87681300e-08, 2.29322650e-08, 1.88653617e-07, 3.28018635e-08,
#        3.97854201e-10, 4.01302758e-08, 1.90321424e-07, 3.40858891e-08,
#        4.18578439e-09, 9.09556473e-08, 3.21881044e-07])

# %%
love_vector.jzazbz_dist
# Out:
# array([ 43.70086125,  82.88902835,  20.36144642, 207.55729541,
#         11.45945804, 131.10485973,  10.49319587, 334.18735373])

# %%
love_vector.colorgram
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x10E5AA9D0>

# %%
love_vector.print_word_color()

# %%
fear_vector = cs.vectors.Vector("fear", path)
# Out:
# fear is being compressed.

# %%
joy_vector = cs.vectors.Vector("joy", path)
# Out:
# joy is being compressed.

# %%
anger_vector = cs.vectors.Vector("anger", path)
# Out:
# anger is being compressed.
